# %%
# !pip install yfinance pandas numpy scipy plotly -q

# %%
exec(open('greek_backtester_free (7).py').read())

# Run both + side-by-side comparison dashboard (recommended)
results = run_comparison()

# Or run individually:
# run_backtest()        ← Iron Condor only
# run_long_straddle()   ← Long Straddle only
# Out:
# ╔══════════════════════════════════════════════════════╗
# ║  NIFTY Strategy Comparison                           ║
# ║  Iron Condor  vs  Long Straddle                      ║
# ║  Data: yfinance  |  Greeks: Black-Scholes            ║
# ╚══════════════════════════════════════════════════════╝
# 📥  Downloading NIFTY 50  [2022-01-01 → 2024-12-31] ...
#     ✅  738 trading days loaded
#     IV/HV ratio range: 0.41 – 1.62  | mean: 1.23
#
# ──────────────────────────────────────────────────────
#   Running: Iron Condor
# ──────────────────────────────────────────────────────
#
# 📅  36 monthly expiry cycles to simulate
#
#   ⏭   2022-02-24 — IV/HV=0.95 < 1.1 (vol not elevated), skip
#   ▶  Entry 2022-02-15 | Expiry 2022-03-31 | Spot ₹17352 | Condor [17100/17600–17750/16950] | Net Prem ₹120.6 | MaxLoss ₹1469 | Lots 3
#      ✅ Exit [TIME_EXIT       ]  P&L ₹  +7,162  |  DTE held: 27
# ...
